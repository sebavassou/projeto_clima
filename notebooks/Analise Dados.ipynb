# %% [markdown]
# # %% [markdown]
# # # 📊 Diagnóstico de Clima Organizacional (Metodologia GPTW & Análise Crítica)
# #
# # **Objetivo:** Realizar uma análise exploratória profunda (EDA) para diagnosticar a saúde organizacional da Administração Pública Federal.
# # **Metodologia:** Baseada nos 5 pilares do Great Place to Work (GPTW): Credibilidade, Respeito, Imparcialidade, Orgulho e Camaradagem.
# # **Escopo:**
# # 1. Limpeza rigorosa (Unidades com > 25 respostas).
# # 2. Diagnóstico dos Pilares.
# # 3. Análise Demográfica (A "Crise dos 11 Anos").
# # 4. Análise Geopolítica (O "Custo Brasília" vs. "Ilhas de Felicidade").

# %%
# %% [code]
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

# Configuração Estética
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
pd.set_option('display.max_columns', None)

# Definição dos Pilares GPTW
PILLARS = ['credibilidade', 'respeito', 'imparcialidade', 'orgulho', 'camaradagem']

# Carregamento
try:
    df_raw = pd.read_csv('br_me_clima_organizacional_microdados.csv')
    print("✅ Dados carregados com sucesso!")
except FileNotFoundError:
    print("❌ Arquivo não encontrado. Verifique o caminho.")
